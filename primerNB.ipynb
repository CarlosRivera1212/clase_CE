# %% [markdown]
# # Mi primer Notebook *Google Colaboratory*

# %% [markdown]
# Podemos escribir texto plano o codigo

# %%
# Este es un chucnk de codigo

print(1+2+3)
# Out:
# 6

# %% [markdown]
# Tambien podemos escribir ecuaciones $\LaTeX$
#
# $$ax^2+bx+c$$
#
# $$\int_{-\infty}^{\infty} f(x) dx$$

# %% [markdown]
# * Una imagen desde la web
#
# ![](https://pbs.twimg.com/profile_images/673704430412283904/40o0qTNj_400x400.png)
#
# [Link de la imagen](https://pbs.twimg.com/profile_images/673704430412283904/40o0qTNj_400x400.png)

# %% [markdown]
# ---
#
# Subir un archivo excel
#
# 1. En el menu izquierdo abrir `files`
# 2. Conectar el `Drive`
# 3. Buscar el archivo dentro de `MyDrive`
# 4. copiar el `path`

# %%
ruta_archivo = '/content/drive/MyDrive/ASIGNATURAS/AAA.AAA.AAA/Computacion Estadistica/Computación Estadística 2022-1/Clases/Clase 1 - 070322/clase1_CE20221.xlsx'

# %% [markdown]
# # Asignación
#
# ### Crear un notbook en google-colaboratory con las siguientes indicaciones:
#
# 1. Cargar un archivo de excel (con una ruta permenanate en drive) (apoyarse en el modulo `pandas`)
#
# 2. colocar una imagen desde internet
#
# 3. Escribir una matrix 4x4 (en $\LaTeX$)
#
# 4. ¿Como crear un tabla? (en $\LaTeX$)
#
# 5. Copiar una ecuación estadistica (en $\LaTeX$)
